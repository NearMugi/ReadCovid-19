# %% [markdown]
# # フォルダ内のファイルリスト(Json型)を出力する

# %% [markdown]
# ## import

# %%
import sys
import os
import json
from WebScrapingTool import Base_UserFunction as uf
import comFunction

# %% [markdown]
# ## フォルダ内のファイル名を取得する

# %%
class getFileList:
    # コンストラクタ
    def __init__(self):
        pass
    
    def getFileType(self, fileName):
        if ".txt" in fileName:
            return "text/plain"
        if ".pdf" in fileName:
            return "application/pdf"
        if ".json" in fileName:
            return "application/json"
        if ".csv" in fileName:
            return "application/octet-stream"
        if ".log" in fileName:
            return "application/octet-stream"            
        return ''

    def getFileListInFolder(self, saveDir, folder):
        retDict = dict()
        path = saveDir + folder
        files = os.listdir(path)
        files = [f for f in files if os.path.isfile(os.path.join(path, f))]
        idx = 0
        for f in files:
            retDict[folder + "_" + str(idx)] = [folder + "/" + f, self.getFileType(f)]
            idx += 1
        return retDict


    def getData(self):
        com = comFunction.common()
        # 設定ファイルから必要な情報を取得する
        # 先頭は必ず SaveDir にする
        tagSaveDir = '[0]'
        tagListFolder = '[b]'
        tagDataFolder = '[B]'

        settingDict = com.getSettingData([
            tagSaveDir,
            tagListFolder,
            tagDataFolder
            ])  
        com.infoMsg(sys._getframe().f_code.co_name, json.dumps(settingDict))

        if len(settingDict) <= 0:
            com.errMsg(sys._getframe().f_code.co_name, 'SettingData is none...')
            return dict(), 1
        saveDir = settingDict[tagSaveDir]
        listFolder = settingDict[tagListFolder]
        dataFolder = settingDict[tagDataFolder]
        retDict = dict()

        if len(listFolder) <= 0:
            print('missing listFolderPath...')
            return retDict, 1
        if len(dataFolder) <= 0:
            print('missing dataFolderPath...')
            return retDict, 1

        # フォルダ内にあるファイル名を取得
        retDict.update(self.getFileListInFolder(saveDir, listFolder))
        retDict.update(self.getFileListInFolder(saveDir, dataFolder))

        return retDict, 0

# %% [markdown]
# ## 処理開始

# %%
if __name__ == '__main__':
    read = getFileList()
    ret, isError = read.getData()
    print(json.dumps(ret))
    sys.exit(isError)
# Out:
# {"list_0": ["list/dataList.json", "application/json"], "list_1": ["list/dataList.json.bk", "application/json"], "list_2": ["list/outputList.csv", "application/octet-stream"], "list_3": ["list/parse.log", "application/octet-stream"], "list_4": ["list/parsePDF.json", "application/json"], "list_5": ["list/parse_20210817213335.log", "application/octet-stream"], "list_6": ["list/parse_20210817230040.log", "application/octet-stream"], "list_7": ["list/parse_20210818225529.log", "application/octet-stream"], "list_8": ["list/parse_20210819223632.log", "application/octet-stream"], "list_9": ["list/parse_20210820214725.log", "application/octet-stream"], "list_10": ["list/parse_20210827231342.log", "application/octet-stream"], "list_11": ["list/parse_20210829130836.log", "application/octet-stream"], "list_12": ["list/parse_20210830214139.log", "application/octet-stream"], "list_13": ["list/parse_20210831215859.log", "application/octet-stream"], "list_14": ["list/parse_20210904215452.log", "application/octet-stream"], "list_15": ["list/parse_20210907225447.log", "application/octet-stream"], "list_16": ["list/parse_20210911233127.log", "application/octet-stream"], "list_17": ["list/parse_20210913174432.log", "application/octet-stream"], "list_18": ["list/parse_20210916211254.log", "application/octet-stream"], "list_19": ["list/prevPressURL.txt", "text/plain"], "data_0": ["data/20200328_131_01.pdf", "application/pdf"], "data_1": ["data/20200328_131_02.pdf", "application/pdf"], "data_2": ["data/20200329_133_01.pdf", "application/pdf"], "data_3": ["data/20200329_133_02.pdf", "application/pdf"], "data_4": ["data/20200401_141.pdf", "application/pdf"], "data_5": ["data/20200402_20_01a.pdf", "application/pdf"], "data_6": ["data/20200403_15_01.pdf", "application/pdf"], "data_7": ["data/20200403_20200403.pdf", "application/pdf"], "data_8": ["data/20200404_01_01.pdf", "application/pdf"], "data_9": ["data/20200405_01_00.pdf", "application/pdf"], "data_10": ["data/20200406_24_00.pdf", "application/pdf"], "data_11": ["data/20200407_23_01.pdf", "application/pdf"], "data_12": ["data/20200409_21.pdf", "application/pdf"], "data_13": ["data/20200409_24_01.pdf", "application/pdf"], "data_14": ["data/20200410_31_01.pdf", "application/pdf"], "data_15": ["data/20200414_20_02.pdf", "application/pdf"], "data_16": ["data/20200415_18_01.pdf", "application/pdf"], "data_17": ["data/20200415_20200414.pdf", "application/pdf"], "data_18": ["data/20200417_10-01.pdf", "application/pdf"], "data_19": ["data/20200417_20200417.pdf", "application/pdf"], "data_20": ["data/20200418_01_00.pdf", "application/pdf"], "data_21": ["data/20200419_01_00.pdf", "application/pdf"], "data_22": ["data/20200420_11_01.pdf", "application/pdf"], "data_23": ["data/20200421_02_00.pdf", "application/pdf"], "data_24": ["data/20200422_18_00.pdf", "application/pdf"], "data_25": ["data/20200423_21_00.pdf", "application/pdf"], "data_26": ["data/20200424_13_00.pdf", "application/pdf"], "data_27": ["data/20200425_262.pdf", "application/pdf"], "data_28": ["data/20200426_264.pdf", "application/pdf"], "data_29": ["data/20200427_16_00.pdf", "application/pdf"], "data_30": ["data/20200428_14_00.pdf", "application/pdf"], "data_31": ["data/20200429_02_00.pdf", "application/pdf"], "data_32": ["data/20200430_14_00.pdf", "application/pdf"], "data_33": ["data/20200501_14_00.pdf", "application/pdf"], "data_34": ["data/20200502_20200502_01.pdf", "application/pdf"], "data_35": ["data/20200503_01_01.pdf", "application/pdf"], "data_36": ["data/20200504_20200504.pdf", "application/pdf"], "data_37": ["data/20200505_05_00.pdf", "application/pdf"], "data_38": ["data/20200506_20200506.pdf", "application/pdf"], "data_39": ["data/20200507_13_01.pdf", "application/pdf"], "data_40": ["data/20200508_11_00.pdf", "application/pdf"], "data_41": ["data/20200509_03_00.pdf", "application/pdf"], "data_42": ["data/20200510_01_00.pdf", "application/pdf"], "data_43": ["data/20200511_14_00.pdf", "application/pdf"], "data_44": ["data/20200512_ ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Teppei\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
