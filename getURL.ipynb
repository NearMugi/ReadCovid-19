# %% [markdown]
# # 東京都福祉保健局のHPから新型コロナウイルスに関連した患者の発生について（過去1週間分）のPDFのURLをテキストに出力
#
# ## 仕様
# - https://www.fukushihoken.metro.tokyo.lg.jp/hodo/saishin/hassei.html からpdfのパスを取得する
# - htmlの解析はBeautifulsoupを使っている。
# - テキストは指定したフォルダへ保存する
#
# ## 構成
# - Setting.text
#   - 設定ファイル
#     - 保存先の親フォルダを指定
# - getURL.py
#   - URLテキスト(json)を出力する
# - getPDF.py
#   - URLテキストからPDFを出力する
# - getParseDataFromPDF.py
#   - PDFファイルを読み込み、パースした情報を取得する
#
# ## URLテキスト(json)の形式
#
# - name : PDFファイル名
# - url : 取得元のURL
# - isGetPDF : PDFファイルを取得している場合はTrue
#
# ### name

# %% [markdown]
# ## import

# %%
import os
import json
from WebScrapingTool import Base_UserFunction as uf

#デバッグモードの指定
#コンストラクタでTrue/Falseを設定
#main()でインスタンスを定義
global DEBUG
class debug:
    #コンストラクタ
    def __init__(self, isDebug):
        global DEBUG
        DEBUG = isDebug
    def printLog(self, msg):
        if DEBUG:
            print(msg)

# %% [markdown]
# ## 基本パーツ

# %%
class base:
    saveFolder = ''
    saveFileName = ''
    baseURL = ''
    topURL = ''
    previousPDFLinkURL = ''
    typeLast = ''
    typePrevious = ''
    dataFormat = ''
    prevPressURLFileName = ''

    prevPressURL = list()
    saveData = list()

    # コンストラクタ
    def __init__(self):
        pass
    
    def setSettingData(self):
        #設定ファイルから必要な情報を取得する
        #タグ
        tag_debug = '[a]'
        tag_saveFolder = '[b]'
        tag_saveFileName = '[c]'
        tag_baseURL = '[d]'
        tag_topURL = '[e]'
        tag_previousPDFLinkURL = '[f]'
        tag_typeLast = '[g]'
        tag_typePrevious = '[h]'
        tag_dataFormat = '[i]'
        tag_prevPressURL = '[m]'
        isDebug = False

        try:
            with open('_Setting.txt', mode='r') as f:
                lines = f.readlines()
                for l in lines:
                    if l.startswith(tag_debug, 0, 3):
                        if (l.replace(tag_debug, '').rstrip()).lower() == 'true':
                            isDebug = True
                        else:
                            isDebug = False                    

                    if l.startswith(tag_saveFolder, 0, 3):
                        self.saveFolder = l.replace(tag_saveFolder, '').rstrip()

                    if l.startswith(tag_saveFileName, 0, 3):
                        self.saveFileName = l.replace(tag_saveFileName, '').rstrip()

                    if l.startswith(tag_baseURL, 0, 3):
                        self.baseURL = l.replace(tag_baseURL, '').rstrip()

                    if l.startswith(tag_topURL, 0, 3):
                        self.topURL = l.replace(tag_topURL, '').rstrip()

                    if l.startswith(tag_previousPDFLinkURL, 0, 3):
                        self.previousPDFLinkURL = l.replace(tag_previousPDFLinkURL, '').rstrip()

                    if l.startswith(tag_typeLast, 0, 3):
                        self.typeLast = l.replace(tag_typeLast, '').rstrip()

                    if l.startswith(tag_typePrevious, 0, 3):
                        self.typePrevious = l.replace(tag_typePrevious, '').rstrip()

                    if l.startswith(tag_dataFormat, 0, 3):
                        self.dataFormat = l.replace(tag_dataFormat, '').rstrip()

                    if l.startswith(tag_prevPressURL, 0, 3):
                        self.prevPressURLFileName = l.replace(tag_prevPressURL, '').rstrip()

        except:
            print('[!!!ERROR!!!] Read Setting Text')

        # 過去プレスリスト作成
#        iFile = self.saveFolder + '/' + self.prevPressURLFileName
#        with open(iFile, mode='r') as fs:
#            for line in fs:
#                self.prevPressURL.append(line)


        return isDebug
        
    def checkInitialize(self):
        if len(self.saveFolder) <= 0:
            print('[!!!ERROR!!!] Save FolderName is Empty!')
            return False    
        if len(self.saveFileName) <= 0:
            print('[!!!ERROR!!!] Save FileName is Empty!')
            return False    
        return True        
        
    def createSaveFolderAndFile(self):
        if not os.path.exists(self.saveFolder):
            os.mkdir(self.saveFolder)
        oFile = self.saveFolder + '/' + self.saveFileName
        if not os.path.exists(oFile):
            f = open(oFile,'w')
            f.close()


    def getSettingData(self):
        return self.baseURL, self.topURL, self.previousPDFLinkURL, self.typeLast, self.typePrevious, self.dataFormat

    def getPrevURL(self):
        return self.prevPressURL

    def setSaveData(self, _data):
        self.saveData.append(_data)
        
    def saveGetData(self):
        print('[Save Data]')
        if len(self.saveData) <= 0:
            print('No Data...')
            return
        
        # リスト作成
        oFile = self.saveFolder + '/' + self.saveFileName

        # 重複データは再度追加しない
        _alreadyGetURL = list()
        with open(oFile, mode='r') as fs:
            for line in fs:
                j = json.loads(line)
                _alreadyGetURL.append(j['url'])
                
        with open(oFile, mode='a') as fs:
            for line in self.saveData:
                j = json.loads(line)
                if not j['url'] in _alreadyGetURL:
                    uf.fileWrite(fs, line)
                else:
                    print('already get url : ' + line)
        # 重複データ削除    
        uf.fileDataSlim(oFile)

# %% [markdown]
# ## スクレイピング本体

# %%
class work:
    baseURL = ''
    topURL = ''
    previousPDFLinkURL = ''
    typeLast = ''
    typePrevious = ''    
    PDFPath = ''
    dataFormat = ''
    #コンストラクタ
    def __init__(self, b):
        self.PDFPath = '<p class="pagelinkout">'
        self.baseURL, self.topURL, self.previousPDFLinkURL, self.typeLast, self.typePrevious, self.dataFormat = b.getSettingData()

    def setSaveData(self, url, isLast):
        name = url.replace("/tosei", "")
        name = name.replace("/hodohappyo", "")
        name = name.replace("/press", "")
        name = name.replace("/documents", "_")
        name = name.replace("/", "")
        fullURL = ''
        type = ''
        if isLast:
            type = self.typeLast
            fullURL = self.baseURL + '/hodo/saishin/' + url
        else:
            type = self.typePrevious
            fullURL = self.previousPDFLinkURL + url 

        _saveData = self.dataFormat + '\n'
        _saveData = _saveData.replace("@@type", type)
        _saveData = _saveData.replace("@@name", name)
        _saveData = _saveData.replace("@@url", fullURL)
        return _saveData
        
    def getURLandSetData(self, d, b):
        _html = uf.getHTML(self.baseURL + self.topURL)
        bs = uf.getBS4(_html)
        #d.printLog(bs.body)

        _linkLastPath = ""
        _linkPrevPath = b.getPrevURL()
        _bsLinkPathList = bs.findAll("p", {"class": "pagelinkout"})
        for _linkList in _bsLinkPathList:
            # last Data
            _bsLinkLastPath = _linkList.find("a", {"class": "innerLink"})
            if _bsLinkLastPath is not None:
                _linkLastPath = self.baseURL + _bsLinkLastPath["href"]

            # previous Data
            _bsLinkPath = _linkList.find("a", {"class": "externalLink"})
            if _bsLinkPath is not None:
                _linkPrevPath.append(_bsLinkPath["href"])
            
        if len(_linkLastPath) <= 0:
            print('[!!!ERROR!!!] Search LinkPath(Last) is Empty!')
            return False
        if len(_linkPrevPath) <= 0:
            print('[!!!ERROR!!!] Search LinkPath(Previous) is Empty!')
            return False

        # Last PDF Link
        print("[get Last PDF Link]")
        print(_linkLastPath)
        _html = uf.getHTML(_linkLastPath)
        bs = uf.getBS4(_html)
        _bsPDFPathList = bs.findAll("a", {"class":"resourceLink newWindow"})
        isLast = True
        for _url in _bsPDFPathList:
            b.setSaveData(self.setSaveData(_url["href"], isLast))
        
        # previous PDF Link
        print("[get Previous PDF Link]")
        for _link in _linkPrevPath:
            print(_link)
            _html = uf.getHTML(_link)
            bs = uf.getBS4(_html)
            _bsPDFPathList = bs.findAll("a", {"class":"icon_pdf"})
            isLast = False
            for _url in _bsPDFPathList:
                b.setSaveData(self.setSaveData(_url["href"], isLast))
        
        return True

# %% [markdown]
# ## 最初に呼ばれる

# %%
def main():  
    print("\n[Start]" + uf.getNowTime() + '\n')            

    b = base()
    isDebug = b.setSettingData()
    if not b.checkInitialize():
        return
    
    # デバッグの設定
    d = debug(isDebug)

    w = work(b)
    
    # 保存フォルダ,ファイル作成
    b.createSaveFolderAndFile()
    
    w.getURLandSetData(d, b)
    b.saveGetData()
    
    
    print("\n[ End ]" + uf.getNowTime() + '\n')

# %% [markdown]
# ## 処理開始

# %%
if __name__ == '__main__':
    main()
# Out:
# [Start]20210730232808
#
# [get Last PDF Link]
# https://www.fukushihoken.metro.tokyo.lg.jp/hodo/saishin/corona2298.html
# [get Previous PDF Link]
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/12/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/27/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/23/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/29/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/17/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/13/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/16/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/14/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/27/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/12/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/19/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/08/28.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/21/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/07/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/15/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/06/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/12/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/06/16.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/26/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/03/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/09/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/12/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/08/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/06/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/09/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/08/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/21/19.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/22/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/06/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/15/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/14/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/24/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/18/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/21/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/18/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/13/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/10/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/17/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/15/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/22/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/21/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/28/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/17/32.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/18/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/29/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/26/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/17/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/08/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/04/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/22/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/10/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/07/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/25/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/23/34.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/18/26.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/12/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/24/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/11/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/07/19.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/07/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/25/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/01/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/10/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/14/08.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/20/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/05/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/09/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/20/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/12/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/30/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/07/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/09/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/05/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/18/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/16/08.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/23/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/01/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/27/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/25/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/25/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/25/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/13/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/17/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/05/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/02/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/14/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/14/33.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/18/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/03/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/11/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/07/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/26/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/30/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/26/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/18/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/16/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/15/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/15/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/12/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/27/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/10/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/09/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/12/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/26/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/29/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/20/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/23/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/04/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/05/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/06/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/08/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/14/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/21/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/29/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/20/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/14/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/06/24.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/23/06.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/19/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/12/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/24/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/13/16.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/16/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/19/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/22/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/25/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/15/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/18/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/28/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/27/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/26/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/01/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/16/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/15/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/25/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/17/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/09/24.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/26/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/15/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/27/40.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/13/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/25/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/13/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/24/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/14/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/06/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/03/16.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/29/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/02/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/04/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/09/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/16/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/20/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/17/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/23/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/14/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/17/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/25/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/12/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/02/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/28/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/26/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/02/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/22/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/08/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/19/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/16/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/07/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/16/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/30/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/11/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/07/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/22/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/28/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/03/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/03/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/22/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/08/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/12/06.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/03/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/29/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/06/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/26/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/04/26.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/21/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/07/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/01/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/03/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/08/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/30/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/04/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/16/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/05/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/20/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/22/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/01/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/14/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/27/16.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/20/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/05/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/12/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/05/08.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/05/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/05/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/01/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/01/27/24.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/26/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/16/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/17/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/15/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/15/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/23/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/29/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/14/04.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/22/04.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/16/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/03/28.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/13/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/19/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/11/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/10/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/28/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/05/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/17/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/03/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/02/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/25/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/21/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/03/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/30/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/18/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/27/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/20/32.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/11/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/19/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/21/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/19/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/16/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/05/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/17/31.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/28/33.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/11/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/03/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/26/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/16/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/30/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/01/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/28/42.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/26/04.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/25/26.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/03/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/20/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/21/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/13/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/01/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/08/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/04/17.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/07/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/23/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/24/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/25/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/24/26.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/13/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/28/05.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/25/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/04/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/23/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/29/05.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/14/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/23/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/21/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/17/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/01/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/28/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/04/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/24/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/21/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/14/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/13/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/25/41.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/15/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/23/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/13/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/10/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/13/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/02/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/12/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/18/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/30/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/11/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/10/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/27/32.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/01/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/13/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/20/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/06/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/22/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/10/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/20/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/07/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/30/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/27/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/20/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/05/28.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/27/24.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/23/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/15/17.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/17/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/02/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/02/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/10/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/06/16.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/19/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/07/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/13/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/04/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/22/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/03/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/08/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/13/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/01/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/07/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/11/16.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/08/36.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/03/17.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/21/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/01/24/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/27/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/29/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/15/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/17/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/06/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/20/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/06/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/28/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/14/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/26/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/04/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/16/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/26/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/22/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/28/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/30/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/01/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/06/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/13/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/04/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/04/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/11/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/03/17.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/23/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/10/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/09/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/09/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/01/16.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/15/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/29/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/11/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/08/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/02/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/01/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/04/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/16/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/17/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/03/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/20/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/17/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/30/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/27/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/19/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/29/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/24/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/27/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/12/28.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/23/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/09/06.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/28/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/10/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/18/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/24/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/09/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/20/17.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/28/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/24/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/18/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/01/36.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/10/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/27/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/01/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/23/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/09/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/19/31.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/27/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/04/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/03/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/18/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/02/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/02/08.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/12/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/25/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/17/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/26/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/24/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/08/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/11/08.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/07/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/20/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/02/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/10/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/07/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/18/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/14/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/01/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/25/28.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/01/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/10/31.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/15/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/05/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/19/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/22/26.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/09/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/22/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/05/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/13/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/15/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/28/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/01/07.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/15/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/10/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/24/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/08/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/04/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/30/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/29/40.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/06/24.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/21/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/29/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/05/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/10/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/09/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/26/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/11/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/27/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/28/17.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/14/07.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/24/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/02/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/30/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/01/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/06/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/07/08.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/04/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/17/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/15/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/11/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/07/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/08/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/17/31.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/23/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/05/05.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/28/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/18/06.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/19/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/27/27.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/18/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/08/15.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/29/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/24/08.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/11/18.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/18/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/10/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/22/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/07/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/12/27.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/09/25.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/18/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/21/17.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/23/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/20/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/09/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/05/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/05/12.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/28/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/19/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/19/30.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/20/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/25/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/19/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/15/11.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/26/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/18/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/18/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/25/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/21/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/04/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/11/10.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/22/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/02/14/32.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/21/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/22/28.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/19/13.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/06/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/11/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/16/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/22/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/02/23.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/02/01.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/21/02.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/28/14.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/11/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/12/03.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/04/04.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/22/22.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/14/21.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/24/20.html
#
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/30/31.html
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/29/30.html
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/28/30.html
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/27/20.html
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/26/20.html
# https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/25/01.html
# [Save Data]
# already get url : {"type" : "Last", "name" : "corona2298.files2298.pdf", "url" : "https://www.fukushihoken.metro.tokyo.lg.jp/hodo/saishin/corona2298.files/2298.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Last", "name" : "corona2298.files2298-2.pdf", "url" : "https://www.fukushihoken.metro.tokyo.lg.jp/hodo/saishin/corona2298.files/2298-2.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200912_20200912.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/12/documents/20200912.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200527_15_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/27/documents/15_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210223_01_01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/02/23/documents/01_01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200429_02_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/29/documents/02_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201217_20201216.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/17/documents/20201216.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200716_22_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/16/documents/22_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201214_20201213.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/14/documents/20201213.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201227_20201227.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/27/documents/20201227.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210412_0412-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/12/documents/press0412-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210519_0519-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/19/documents/press0519-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210108_28_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/08/documents/28_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200521_20200521-13.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/21/documents/20200521-13.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200515_15_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/15/documents/15_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210606_20210606_01_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/06/documents/20210606_01_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210606_20210606_01_2.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/06/documents/20210606_01_2.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201006_16_00a.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/06/documents/16_00a.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201026_20201024a.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/26/documents/20201024a.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200603_01_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/03/documents/01_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200909_0909-11.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/09/documents/0909-11.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210612_0612-01-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/12/documents/press0612-01-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210612_0612-01-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/12/documents/press0612-01-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200908_0908-11.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/08/documents/0908-11.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210106_20210105.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/06/documents/20210105.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210309_20210309_20_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/09/documents/20210309_20_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210308_20210308_20_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/08/documents/20210308_20_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210722_0722-01-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/22/documents/press0722-01-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210722_0722-01-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/22/documents/press0722-01-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210706_0706-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/06/documents/press0706-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210706_0706-20-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/06/documents/press0706-20-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200415_18_01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/15/documents/18_01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200514_10_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/14/documents/10_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210524_0524-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/24/documents/press0524-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200418_01_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/18/documents/01_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200621_01_01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/21/documents/01_01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210418_0418-01-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/18/documents/press0418-01-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210713_0713-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/13/documents/press0713-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210713_0713-20-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/13/documents/press0713-20-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201010_01_00a.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/10/documents/01_00a.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200617_20200617.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/17/documents/20200617.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210615_0615-30-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/15/documents/press0615-30-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210615_0615-30-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/15/documents/press0615-30-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200922_20200922.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/22/documents/20200922.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# ...
#
# already get url : {"type" : "Previous", "name" : "20210317_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/17/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200715_20200715.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/15/documents/20200715.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210311_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/11/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201107_20201107.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/07/documents/20201107.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210508_20210508_01_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/08/documents/20210508_01_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200723_20200723.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/23/documents/20200723.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200505_05_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/05/documents/05_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200328_131_01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/28/documents/131_01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200328_131_02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/03/28/documents/131_02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200818_20200818.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/18/documents/20200818.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210419_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/19/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201127_27_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/27/documents/27_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201208_20201207_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/08/documents/20201207_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210629_0629-30-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/29/documents/press0629-30-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210629_0629-30-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/29/documents/press0629-30-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200824_08_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/24/documents/08_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200611_18_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/11/documents/18_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201018_20201018.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/18/documents/20201018.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210510_20210510_20_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/10/documents/20210510_20_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201007_1007-10b.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/07/documents/1007-10b.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201012_20201012.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/12/documents/20201012.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200709_20200709.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/09/documents/20200709.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200518_20200518-11.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/18/documents/20200518-11.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200721_17_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/21/documents/17_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210523_20210523.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/23/documents/20210523.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210620_0620-01-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/20/documents/press0620-01-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210620_0620-01-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/20/documents/press0620-01-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201209_1209_1149.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/09/documents/1209_1149.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210405_0405-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/05/documents/press0405-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200805_12_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/05/documents/12_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210128_20210127_01_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/28/documents/20210127_01_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200719_20200719.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/19/documents/20200719.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200620_01_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/20/documents/01_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200825_20200825.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/25/documents/20200825.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210119_20210119-20_02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/19/documents/20210119-20_02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200415_20200414.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/15/documents/20200414.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210326_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/26/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210518_20210518_23_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/18/documents/20210518_23_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201118_21_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/11/18/documents/21_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210125_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/25/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210321_01_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/21/documents/01_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200904_20200904.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/04/documents/20200904.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210322_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/22/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210521_0521-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/05/21/documents/press0521-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201022_20201022.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/10/22/documents/20201022.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200819_13_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/19/documents/13_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200606_01_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/06/06/documents/01_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210611_0611-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/11/documents/press0611-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210611_0611-20-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/06/11/documents/press0611-20-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210416_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/16/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200522_14_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/05/22/documents/14_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200902_23_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/09/02/documents/23_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200802_20200802.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/08/02/documents/20200802.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200421_02_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/21/documents/02_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200428_14_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/04/28/documents/14_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201211_1211_1159.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/11/documents/1211_1159.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20201212_20201211.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/12/12/documents/20201211.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210104_20210103.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/01/04/documents/20210103.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20200722_20200722.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2020/07/22/documents/20200722.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210414_20210414_21_1.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/04/14/documents/20210414_21_1.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210324_20.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/03/24/documents/20.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210730_0730-31-01a.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/30/documents/press0730-31-01a.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210730_0730-31-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/30/documents/press0730-31-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210729_0729-30-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/29/documents/press0729-30-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210729_0729-30-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/29/documents/press0729-30-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210728_0728-30-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/28/documents/press0728-30-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210728_0728-30-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/28/documents/press0728-30-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210727_0727-20-01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/27/documents/press0727-20-01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210727_0727-20-02.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/27/documents/press0727-20-02.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210726_20_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/26/documents/20_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210726_20_01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/26/documents/20_01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210725_01_00.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/25/documents/01_00.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
# already get url : {"type" : "Previous", "name" : "20210725_01_01.pdf", "url" : "https://www.metro.tokyo.lg.jp/tosei/hodohappyo/press/2021/07/25/documents/01_01.pdf", "isGetPDF" : "False", "isParse" : "False" }
#
#
# [ End ]20210730232841
